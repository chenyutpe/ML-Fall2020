# %%
import numpy as np
import pandas as pd
import random

# %%
#!nvidia-smi

# %%
test = pd.read_csv('/test.csv')
test_nolabel = pd.read_csv('/content/drive/MyDrive/MLfinal/test_nolabel.csv')
train = pd.read_csv('/content/drive/MyDrive/MLfinal/train.csv')
train_label = pd.read_csv('/content/drive/MyDrive/MLfinal/train_label.csv')

# %%
train.isna().sum()
# Out:
# ID                                    0
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             468
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# ...

# %%
df = train.drop(['ID', 'is_canceled', 'adr', 'reservation_status', 'reservation_status_date'], axis=1)
df.describe
# Out:
# <bound method NDFrame.describe of               hotel  ...  total_of_special_requests
# 0      Resort Hotel  ...                          0
# 1        City Hotel  ...                          0
# 2        City Hotel  ...                          0
# 3        City Hotel  ...                          0
# 4        City Hotel  ...                          0
# ...             ...  ...                        ...
# 91526  Resort Hotel  ...                          1
# 91527  Resort Hotel  ...                          0
# 91528  Resort Hotel  ...                          2
# 91529  Resort Hotel  ...                          1
# 91530  Resort Hotel  ...                          1
#
# [91531 rows x 28 columns]>

# %%
# kill cols with NaNs
df = df.drop(['children', 'country', 'agent', 'company'], axis=1)
df.describe
# Out:
# <bound method NDFrame.describe of               hotel  ...  total_of_special_requests
# 0      Resort Hotel  ...                          0
# 1        City Hotel  ...                          0
# 2        City Hotel  ...                          0
# 3        City Hotel  ...                          0
# 4        City Hotel  ...                          0
# ...             ...  ...                        ...
# 91526  Resort Hotel  ...                          1
# 91527  Resort Hotel  ...                          0
# 91528  Resort Hotel  ...                          2
# 91529  Resort Hotel  ...                          1
# 91530  Resort Hotel  ...                          1
#
# [91531 rows x 24 columns]>

# %%
import datetime
df['arrival_date_month'] = df['arrival_date_month'].apply(lambda x: datetime.datetime.strptime(x, "%B").month)

# %%
dummy = pd.get_dummies(df)
dummy
# Out:
#        lead_time  ...  customer_type_Transient-Party
# 0            342  ...                              0
# 1            257  ...                              0
# 2            257  ...                              0
# 3            257  ...                              0
# 4            257  ...                              0
# ...          ...  ...                            ...
# 91526         19  ...                              0
# 91527         28  ...                              0
# 91528          2  ...                              0
# 91529         30  ...                              0
# 91530          1  ...                              0
#
# [91531 rows x 65 columns]

# %%
reservation_status = pd.get_dummies(train['reservation_status'])

# %%
cancel = train['is_canceled']
adr = train['adr']

# %%
'''from xgboost import XGBClassifier
xgbc_cancel = XGBClassifier()
xgbc_cancel.fit(dummy, cancel)
xgbc_cancel.score(dummy, cancel)
xgbc_adr = XGBClassifier(booster='gblinear', objective='reg:linear')
xgbc_adr.fit(dummy, adr)
xgbc_adr.score(dummy, adr)'''
# Out:
# "from xgboost import XGBClassifier\nxgbc_cancel = XGBClassifier()\nxgbc_cancel.fit(dummy, cancel)\nxgbc_cancel.score(dummy, cancel)\nxgbc_adr = XGBClassifier(booster='gblinear', objective='reg:linear')\nxgbc_adr.fit(dummy, adr)\nxgbc_adr.score(dummy, adr)"

# %%
# train.info()

# %%
'''d = test_nolabel.copy()
randlist = [random.randrange(0, 10, 1) for i in range(153)]
d['label'] = randlist
print(d)'''
# Out:
# "d = test_nolabel.copy()\nrandlist = [random.randrange(0, 10, 1) for i in range(153)]\nd['label'] = randlist\nprint(d)"

# %%
'''d.to_csv('result.csv',index=False)'''
# Out:
# "d.to_csv('result.csv',index=False)"

# %%
from sklearn import svm

# %%
clf=svm.SVC(kernel='rbf',C=1,gamma='auto')
clf.fit(dummy,cancel)
clf.score(dummy,cancel)
# Out:
# 0.8438234040926025

# %%
svr = svm.SVR()
svr.fit(dummy,adr)
svr.score(dummy,adr)
# Out:
# 0.08431113053279005
